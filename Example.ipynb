# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from STS import STSSolution
sol = STSSolution("AB40_S21vsFvsV_fr6.03_6.05_Pr-80_V-1.5_1.5_0.1_T0.084_Cav2_143704_mag.dat", g_guess = 50 * 10e-3)
sol.curve_fit_STS()
sol.extract_hamiltonian_params()
# Out:
# Data read in successfully. Continue processing
# Attempting a curve fit solution to extract hamiltonian parameters
# Attempting to minimize loss function for Hamiltonian parameters
# /home/matt/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:787: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Loss function minimized successfully
# 	 Saving hamiltonian params to solution object

# %%
plt.figure(figsize=(12,12))
plt.plot(sol.interp_volt_axis, sol.f_function(sol.interp_volt_axis, \
                        sol.fc_param, sol.g_param, sol.fmax_ge_param, sol.d_param, sol.period, sol.voltage_sweet_spot), label='Fit')
plt.plot(sol.interp_volt_axis, sol.interp_min_freq, label='Data')
plt.plot(sol.volt_span, sol.minimum_frequencies,label='not-interp')
plt.legend()
plt.show()

# %%
sol.visualize_duty_phi()
# Out:
# (<Figure size 864x864 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9512f4deb8>,
# ...
#        dtype=object))

# %%
fig = sol.visualize_data()

# %%
sol.fc_param
# Out:
# 6.02104641704219

# %%
sol.fmax_ge_param
# Out:
# 4.838843253916787

# %%
sol.g_param
# Out:
# 0.1870298304132454

# %%
sol.d_param
# Out:
# 0.5760112106155383

# %%
sol.period
# Out:
# 2.268380956546358

# %%
sol.voltage_sweet_spot
# Out:
# -0.4145990477556981
